# %%
from dotenv import load_dotenv
load_dotenv()

from ingest import load_faq_data, build_index
from rag_helper import RAGBase
from openai import OpenAI

documents = load_faq_data()
index = build_index(documents)

openai_client = OpenAI()

assistant = RAGBase(
    index=index,
    llm_client=openai_client,
)

# %%
answer = assistant.rag('Until which date can I join the course')
print(answer)
# Out:
# You can join anytime while the course is still running, but if you want a certificate, you need to submit your project before submissions close.

# %%
# Overriding instructions if a different behaviour is desired
custom_instructions = '''
You're a course teaching assistant.
I one and only one sentence, answer the QUESTION based on the CONTEXT from the FAQ database.
Use only the facts from the CONTEXT when answering the QUESTION.
'''.strip()

assistant = RAGBase(
    index=index,
    llm_client=openai_client,
    instructions=custom_instructions,
)

# %%
# assistant.rag("How much time do I have to complete each module?")
# Out:
# 'There is no separate time limit given for completing each module in the provided course materials.'

# %%
# assistant.rag("What's the deadline for submitting the project?")
